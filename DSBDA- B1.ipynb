# %% [markdown]
# ## Perform the following operations using Python on the Facebook metrics data sets
# a. Create data subsets
# b. Merge Data
# c. Sort Data
# d. Transposing Data
# e. Shape and reshape Data

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('dataset_Facebook.csv');

# %%
df
# Out:
#     Page total likes;Type;Category;Post Month;Post Weekday;Post Hour;Paid;Lifetime Post Total Reach;Lifetime Post Total Impressions;Lifetime Engaged Users;Lifetime Post Consumers;Lifetime Post Consumptions;Lifetime Post Impressions by people who have liked your Page;Lifetime Post reach by people who like your Page;Lifetime People who have liked your Page and engaged with your post;comment;like;share;Total Interactions
# 0    139441;Photo;2;12;4;3;0;2752;5091;178;109;159;...
# 1    139441;Status;2;12;3;10;0;10460;19057;1457;136...
# 2    139441;Photo;3;12;3;3;0;2413;4373;177;113;154;...
# 3    139441;Photo;2;12;2;10;1;50128;87991;2211;790;...
# 4    139441;Photo;2;12;2;3;0;7244;13594;671;410;580...
# ..                                                 ...
# 495  85093;Photo;3;1;7;2;0;4684;7536;733;708;985;47...
# 496  81370;Photo;2;1;5;8;0;3480;6229;537;508;687;39...
# 497  81370;Photo;1;1;5;2;0;3778;7216;625;572;795;47...
# 498  81370;Photo;3;1;4;11;0;4156;7564;626;574;832;4...
# ...

# %%
print(df.isnull().sum());
# Out:
# Page total likes;Type;Category;Post Month;Post Weekday;Post Hour;Paid;Lifetime Post Total Reach;Lifetime Post Total Impressions;Lifetime Engaged Users;Lifetime Post Consumers;Lifetime Post Consumptions;Lifetime Post Impressions by people who have liked your Page;Lifetime Post reach by people who like your Page;Lifetime People who have liked your Page and engaged with your post;comment;like;share;Total Interactions    0
# dtype: int64

# %%
df.head(5)
# Out:
#   Page total likes;Type;Category;Post Month;Post Weekday;Post Hour;Paid;Lifetime Post Total Reach;Lifetime Post Total Impressions;Lifetime Engaged Users;Lifetime Post Consumers;Lifetime Post Consumptions;Lifetime Post Impressions by people who have liked your Page;Lifetime Post reach by people who like your Page;Lifetime People who have liked your Page and engaged with your post;comment;like;share;Total Interactions
# 0  139441;Photo;2;12;4;3;0;2752;5091;178;109;159;...
# 1  139441;Status;2;12;3;10;0;10460;19057;1457;136...
# 2  139441;Photo;3;12;3;3;0;2413;4373;177;113;154;...
# 3  139441;Photo;2;12;2;10;1;50128;87991;2211;790;...
# 4  139441;Photo;2;12;2;3;0;7244;13594;671;410;580...

# %%
ds = pd.read_csv('dataset_Facebook.csv', delimiter=';')  # Assuming it's tab-separated

# %%
ds
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# ### Creating 2 data subsets

# %%
subset1 = ds[ds['Page total likes'] <= 100000];

# %%
subset1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 438             98195   Link         2           3             6          6
# 439             98195  Photo         1           3             6          3
# 440             98195  Photo         1           3             5         10
# 441             98195  Photo         1           3             5          4
# 442             98195  Photo         3           3             4         13
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
subset2 = ds[ds['Page total likes'] > 100000];

# %%
subset2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 433            100732   Photo         1           3             6         17
# 434            100732   Photo         1           3             6         15
# 435            100732   Photo         1           3             6         15
# 436            100732   Photo         1           3             6         13
# 437            100732   Photo         1           3             6         10
#
# ...

# %% [markdown]
# ### Merge Data

# %%
merged_data = pd.merge(subset1, subset2,on='Type',how='inner')

# %%
merged_data.head(5)
# Out:
#    Page total likes_x  Type  Category_x  Post Month_x  Post Weekday_x  \
# 0               98195  Link           2             3               6
# 1               98195  Link           2             3               6
# 2               98195  Link           2             3               6
# 3               98195  Link           2             3               6
# 4               98195  Link           2             3               6
#
#    Post Hour_x  Paid_x  Lifetime Post Total Reach_x  \
# 0            6     0.0                         5730
# 1            6     0.0                         5730
# 2            6     0.0                         5730
# 3            6     0.0                         5730
# 4            6     0.0                         5730
#
#    Lifetime Post Total Impressions_x  Lifetime Engaged Users_x  ...  \
# 0                              10083                       103  ...
# 1                              10083                       103  ...
# ...

# %% [markdown]
# ### Sort Data

# %%
sorted_data=merged_data.sort_values(by='Page total likes_x', ascending=True)

# %%
sorted_data
# Out:
#        Page total likes_x   Type  Category_x  Post Month_x  Post Weekday_x  \
# 20815               81370  Photo           2             1               4
# 19848               81370  Photo           1             1               5
# 19849               81370  Photo           1             1               5
# 19850               81370  Photo           1             1               5
# 19851               81370  Photo           1             1               5
# ...                   ...    ...         ...           ...             ...
# 1081                98195  Photo           1             3               5
# 1082                98195  Photo           1             3               5
# 1083                98195  Photo           1             3               5
# 1074                98195  Photo           1             3               5
# 0                   98195   Link           2             3               6
#
#        Post Hour_x  Paid_x  Lifetime Post Total Reach_x  \
# ...

# %%
sort_data=sorted_data

# %%
sort_data
# Out:
#        Page total likes_x   Type  Category_x  Post Month_x  Post Weekday_x  \
# 20815               81370  Photo           2             1               4
# 19848               81370  Photo           1             1               5
# 19849               81370  Photo           1             1               5
# 19850               81370  Photo           1             1               5
# 19851               81370  Photo           1             1               5
# ...                   ...    ...         ...           ...             ...
# 1081                98195  Photo           1             3               5
# 1082                98195  Photo           1             3               5
# 1083                98195  Photo           1             3               5
# 1074                98195  Photo           1             3               5
# 0                   98195   Link           2             3               6
#
#        Post Hour_x  Paid_x  Lifetime Post Total Reach_x  \
# ...

# %% [markdown]
# ### Transposing Data

# %%
transpo_data=sorted_data.transpose()

# %%
transpo_data
# Out:
#                                                      20815   19848   19849  \
# Page total likes_x                                   81370   81370   81370
# Type                                                 Photo   Photo   Photo
# Category_x                                               2       1       1
# Post Month_x                                             1       1       1
# Post Weekday_x                                           4       5       5
# Post Hour_x                                              4       2       2
# Paid_x                                                 NaN     0.0     0.0
# Lifetime Post Total Reach_x                           4188    3778    3778
# Lifetime Post Total Impressions_x                     7292    7216    7216
# Lifetime Engaged Users_x                               564     625     625
# Lifetime Post Consumers_x                              524     572     572
# ...

# %% [markdown]
# ### Shape and Reshape

# %%
sort_data.shape
# Out:
# (20816, 37)

# %%
reshaped_data = pd.melt(sort_data, id_vars=['Type', 'Category_x', 'Post Month_x'], var_name='Variable', value_name='Value')

# %%
reshaped_data
# Out:
#          Type  Category_x  Post Month_x              Variable    Value
# 0       Photo           2             1    Page total likes_x  81370.0
# 1       Photo           1             1    Page total likes_x  81370.0
# 2       Photo           1             1    Page total likes_x  81370.0
# 3       Photo           1             1    Page total likes_x  81370.0
# 4       Photo           1             1    Page total likes_x  81370.0
# ...       ...         ...           ...                   ...      ...
# 707739  Photo           1             3  Total Interactions_y    234.0
# 707740  Photo           1             3  Total Interactions_y    363.0
# 707741  Photo           1             3  Total Interactions_y    155.0
# 707742  Photo           1             3  Total Interactions_y     66.0
# 707743   Link           2             3  Total Interactions_y     18.0
#
# [707744 rows x 5 columns]

# %%
reshaped_data.shape
# Out:
# (707744, 5)

# %%
this shell is for theory purpose 

delete it 

Certainly! Let's break down the code step by step:

1. **Importing Libraries**: 
    ```python
    import pandas as pd
    import numpy as np
    ```

    Here, we import the Pandas library and NumPy library with the aliases `pd` and `np`, respectively. Pandas is used for data manipulation and analysis, while NumPy is often used for numerical operations and array handling.

2. **Reading the Dataset**:
    ```python
    df = pd.read_csv('dataset_Facebook.csv')
    ```

    This line reads a CSV file named `'dataset_Facebook.csv'` into a Pandas DataFrame named `df`.

3. **Checking for Missing Values**:
    ```python
    print(df.isnull().sum())
    ```

    This line prints the count of missing values in each column of the DataFrame `df`.

4. **Displaying the First Few Rows**:
    ```python
    df.head(5)
    ```

    This line displays the first five rows of the DataFrame `df`.

5. **Reading the Dataset with a Different Delimiter**:
    ```python
    ds = pd.read_csv('dataset_Facebook.csv', delimiter=';')
    ```

    Here, the dataset is read again, assuming a different delimiter (`;`) for separating values in the CSV file.

6. **Creating Subsets based on a Condition**:
    ```python
    subset1 = ds[ds['Page total likes'] <= 100000]
    subset2 = ds[ds['Page total likes'] > 100000]
    ```

    Two subsets (`subset1` and `subset2`) are created based on the condition of the `'Page total likes'` column.

7. **Merging Subsets**:
    ```python
    merged_data = pd.merge(subset1, subset2, on='Type', how='inner')
    ```

    The subsets `subset1` and `subset2` are merged on the common column `'Type'` using an inner join.

8. **Sorting Data**:
    ```python
    sorted_data = merged_data.sort_values(by='Page total likes_x', ascending=True)
    ```

    The merged data is sorted based on the `'Page total likes_x'` column in ascending order.

9. **Transposing Data**:
    ```python
    transpo_data = sorted_data.transpose()
    ```

    The sorted data is transposed, swapping rows and columns.

10. **Getting the Shape of Data**:
    ```python
    sort_data.shape
    ```

    The shape of the DataFrame `sort_data` is retrieved, indicating the number of rows and columns.

11. **Reshaping Data**:
    ```python
    reshaped_data = pd.melt(sort_data, id_vars=['Type', 'Category_x', 'Post Month_x'], var_name='Variable', value_name='Value')
    ```

    The DataFrame `sort_data` is melted, converting it from wide to long format, with specified identifier variables (`id_vars`) and variable and value names (`var_name` and `value_name`).

12. **Displaying Reshaped Data**:
    ```python
    reshaped_data
    ```

    Finally, the reshaped DataFrame `reshaped_data` is displayed.

Each step performs specific operations on the dataset using Pandas DataFrame methods and functions to manipulate, analyze, and reshape the data.
# Out:
#   Cell In[1], line 5
#     Certainly! Let's break down the code step by step:
#                   ^
# SyntaxError: unterminated string literal (detected at line 5)
